# %% [markdown]
# ## Topic Modelling after Sentiment Analysis
# ### Using TF-IDF & NMF (Non-negative Matrix Factorization) Algorithm

# %%
#pip install nltk

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMFF

# %%
raw_dataset = pd.read_csv('mabel.txt', header = None, on_bad_lines='warn', encoding = 'utf8')
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_7280\3521165064.py:1: ParserWarning: Skipping line 23: expected 2 fields, saw 6
# Skipping line 44: expected 2 fields, saw 3
#
#   raw_dataset = pd.read_csv('mabel.txt', header = None, on_bad_lines='warn', encoding = 'utf8')

# %%
raw_dataset
# Out:
#            0                                                  1
# 0   05/12/19   1:42 pm - Messages to this chat and calls are...
# 1   05/12/19   1:42 pm - Mabel Infoziant: Hi this is Mabel w...
# 2   05/12/19   1:42 pm - Mabel Infoziant: What’s your full name
# 3   05/12/19                      1:42 pm - AR❤: Ramisha Rani K
# 4   05/12/19                      1:42 pm - Mabel Infoziant: Ok
# 5   05/12/19   1:42 pm - Mabel Infoziant: ramisharanik@gmail...
# 6   05/12/19          1:43 pm - Mabel Infoziant: Your email Id?
# 7   05/12/19                             1:43 pm - AR❤: Yes Mam
# 8   05/12/19   1:43 pm - Mabel Infoziant: I will send 2 abst...
# 9   05/12/19                            1:43 pm - AR❤: Yeah mam
# 10  05/12/19   1:43 pm - Mabel Infoziant: Give me the list t...
# 11  05/12/19   1:43 pm - Mabel Infoziant: Send me cbe office...
# 12  05/12/19   1:44 pm - AR❤: Yeah Mam within Evening I will...
# 13  05/12/19   1:45 pm - AR❤: Tomorrow I have to visit the o...
# ...

# %%
df = raw_dataset

# %%
df.columns = ['Date','Chat']

# %%
df
# Out:
#         Date                                               Chat
# 0   05/12/19   1:42 pm - Messages to this chat and calls are...
# 1   05/12/19   1:42 pm - Mabel Infoziant: Hi this is Mabel w...
# 2   05/12/19   1:42 pm - Mabel Infoziant: What’s your full name
# 3   05/12/19                      1:42 pm - AR❤: Ramisha Rani K
# 4   05/12/19                      1:42 pm - Mabel Infoziant: Ok
# 5   05/12/19   1:42 pm - Mabel Infoziant: ramisharanik@gmail...
# 6   05/12/19          1:43 pm - Mabel Infoziant: Your email Id?
# 7   05/12/19                             1:43 pm - AR❤: Yes Mam
# 8   05/12/19   1:43 pm - Mabel Infoziant: I will send 2 abst...
# 9   05/12/19                            1:43 pm - AR❤: Yeah mam
# 10  05/12/19   1:43 pm - Mabel Infoziant: Give me the list t...
# 11  05/12/19   1:43 pm - Mabel Infoziant: Send me cbe office...
# 12  05/12/19   1:44 pm - AR❤: Yeah Mam within Evening I will...
# 13  05/12/19   1:45 pm - AR❤: Tomorrow I have to visit the o...
# ...

# %%
df = df.drop(0)

# %%
df
# Out:
#         Date                                               Chat
# 1   05/12/19   1:42 pm - Mabel Infoziant: Hi this is Mabel w...
# 2   05/12/19   1:42 pm - Mabel Infoziant: What’s your full name
# 3   05/12/19                      1:42 pm - AR❤: Ramisha Rani K
# 4   05/12/19                      1:42 pm - Mabel Infoziant: Ok
# 5   05/12/19   1:42 pm - Mabel Infoziant: ramisharanik@gmail...
# 6   05/12/19          1:43 pm - Mabel Infoziant: Your email Id?
# 7   05/12/19                             1:43 pm - AR❤: Yes Mam
# 8   05/12/19   1:43 pm - Mabel Infoziant: I will send 2 abst...
# 9   05/12/19                            1:43 pm - AR❤: Yeah mam
# 10  05/12/19   1:43 pm - Mabel Infoziant: Give me the list t...
# 11  05/12/19   1:43 pm - Mabel Infoziant: Send me cbe office...
# 12  05/12/19   1:44 pm - AR❤: Yeah Mam within Evening I will...
# 13  05/12/19   1:45 pm - AR❤: Tomorrow I have to visit the o...
# 14  05/12/19                      1:48 pm - Mabel Infoziant: ok
# ...

# %% [markdown]
# ### Splitting Message --> Time, Name & Message

# %%
Message = df['Chat'].str.split('-',n=1,expand=True)

# %%
Message
# Out:
#              0                                                  1
# 1     1:42 pm     Mabel Infoziant: Hi this is Mabel we just spoke
# 2     1:42 pm              Mabel Infoziant: What’s your full name
# 3     1:42 pm                                 AR❤: Ramisha Rani K
# 4     1:42 pm                                 Mabel Infoziant: Ok
# 5     1:42 pm             Mabel Infoziant: ramisharanik@gmail.com
# 6     1:43 pm                     Mabel Infoziant: Your email Id?
# 7     1:43 pm                                        AR❤: Yes Mam
# 8     1:43 pm    Mabel Infoziant: I will send 2 abstracts for ...
# 9     1:43 pm                                       AR❤: Yeah mam
# 10    1:43 pm    Mabel Infoziant: Give me the list that u have...
# 11    1:43 pm    Mabel Infoziant: Send me cbe office address a...
# 12    1:44 pm    AR❤: Yeah Mam within Evening I will forward y...
# 13    1:45 pm    AR❤: Tomorrow I have to visit the office.yet ...
# ...

# %%
Message.columns = ['Time', 'Chat']
Message
# Out:
#           Time                                               Chat
# 1     1:42 pm     Mabel Infoziant: Hi this is Mabel we just spoke
# 2     1:42 pm              Mabel Infoziant: What’s your full name
# 3     1:42 pm                                 AR❤: Ramisha Rani K
# 4     1:42 pm                                 Mabel Infoziant: Ok
# 5     1:42 pm             Mabel Infoziant: ramisharanik@gmail.com
# 6     1:43 pm                     Mabel Infoziant: Your email Id?
# 7     1:43 pm                                        AR❤: Yes Mam
# 8     1:43 pm    Mabel Infoziant: I will send 2 abstracts for ...
# 9     1:43 pm                                       AR❤: Yeah mam
# 10    1:43 pm    Mabel Infoziant: Give me the list that u have...
# 11    1:43 pm    Mabel Infoziant: Send me cbe office address a...
# 12    1:44 pm    AR❤: Yeah Mam within Evening I will forward y...
# 13    1:45 pm    AR❤: Tomorrow I have to visit the office.yet ...
# ...

# %%
df
# Out:
#         Date                                               Chat
# 1   05/12/19   1:42 pm - Mabel Infoziant: Hi this is Mabel w...
# 2   05/12/19   1:42 pm - Mabel Infoziant: What’s your full name
# 3   05/12/19                      1:42 pm - AR❤: Ramisha Rani K
# 4   05/12/19                      1:42 pm - Mabel Infoziant: Ok
# 5   05/12/19   1:42 pm - Mabel Infoziant: ramisharanik@gmail...
# 6   05/12/19          1:43 pm - Mabel Infoziant: Your email Id?
# 7   05/12/19                             1:43 pm - AR❤: Yes Mam
# 8   05/12/19   1:43 pm - Mabel Infoziant: I will send 2 abst...
# 9   05/12/19                            1:43 pm - AR❤: Yeah mam
# 10  05/12/19   1:43 pm - Mabel Infoziant: Give me the list t...
# 11  05/12/19   1:43 pm - Mabel Infoziant: Send me cbe office...
# 12  05/12/19   1:44 pm - AR❤: Yeah Mam within Evening I will...
# 13  05/12/19   1:45 pm - AR❤: Tomorrow I have to visit the o...
# 14  05/12/19                      1:48 pm - Mabel Infoziant: ok
# ...

# %%
df['Time'] = Message['Time']

# %%
df
# Out:
#         Date                                               Chat        Time
# 1   05/12/19   1:42 pm - Mabel Infoziant: Hi this is Mabel w...    1:42 pm
# 2   05/12/19   1:42 pm - Mabel Infoziant: What’s your full name    1:42 pm
# 3   05/12/19                      1:42 pm - AR❤: Ramisha Rani K    1:42 pm
# 4   05/12/19                      1:42 pm - Mabel Infoziant: Ok    1:42 pm
# 5   05/12/19   1:42 pm - Mabel Infoziant: ramisharanik@gmail...    1:42 pm
# 6   05/12/19          1:43 pm - Mabel Infoziant: Your email Id?    1:43 pm
# 7   05/12/19                             1:43 pm - AR❤: Yes Mam    1:43 pm
# 8   05/12/19   1:43 pm - Mabel Infoziant: I will send 2 abst...    1:43 pm
# 9   05/12/19                            1:43 pm - AR❤: Yeah mam    1:43 pm
# 10  05/12/19   1:43 pm - Mabel Infoziant: Give me the list t...    1:43 pm
# 11  05/12/19   1:43 pm - Mabel Infoziant: Send me cbe office...    1:43 pm
# ...

# %%
Message1 = Message['Chat'].str.split(':', n=1, expand=True)

# %%
Message1
# Out:
#                    0                                                  1
# 1    Mabel Infoziant                     Hi this is Mabel we just spoke
# 2    Mabel Infoziant                              What’s your full name
# 3                AR❤                                     Ramisha Rani K
# 4    Mabel Infoziant                                                 Ok
# 5    Mabel Infoziant                             ramisharanik@gmail.com
# 6    Mabel Infoziant                                     Your email Id?
# 7                AR❤                                            Yes Mam
# 8    Mabel Infoziant     I will send 2 abstracts for u to start working
# 9                AR❤                                           Yeah mam
# 10   Mabel Infoziant                   Give me the list that u have too
# 11   Mabel Infoziant   Send me cbe office address and phone number I...
# 12               AR❤    Yeah Mam within Evening I will forward you mam.
# ...

# %%
Message1.columns = ['Name','Chat']
Message1
# Out:
#                 Name                                               Chat
# 1    Mabel Infoziant                     Hi this is Mabel we just spoke
# 2    Mabel Infoziant                              What’s your full name
# 3                AR❤                                     Ramisha Rani K
# 4    Mabel Infoziant                                                 Ok
# 5    Mabel Infoziant                             ramisharanik@gmail.com
# 6    Mabel Infoziant                                     Your email Id?
# 7                AR❤                                            Yes Mam
# 8    Mabel Infoziant     I will send 2 abstracts for u to start working
# 9                AR❤                                           Yeah mam
# 10   Mabel Infoziant                   Give me the list that u have too
# 11   Mabel Infoziant   Send me cbe office address and phone number I...
# 12               AR❤    Yeah Mam within Evening I will forward you mam.
# ...

# %%
df['Name'] = Message1['Name']

# %%
df['Message'] = Message1['Chat']

# %%
df
# Out:
#         Date                                               Chat        Time  \
# 1   05/12/19   1:42 pm - Mabel Infoziant: Hi this is Mabel w...    1:42 pm
# 2   05/12/19   1:42 pm - Mabel Infoziant: What’s your full name    1:42 pm
# 3   05/12/19                      1:42 pm - AR❤: Ramisha Rani K    1:42 pm
# 4   05/12/19                      1:42 pm - Mabel Infoziant: Ok    1:42 pm
# 5   05/12/19   1:42 pm - Mabel Infoziant: ramisharanik@gmail...    1:42 pm
# 6   05/12/19          1:43 pm - Mabel Infoziant: Your email Id?    1:43 pm
# 7   05/12/19                             1:43 pm - AR❤: Yes Mam    1:43 pm
# 8   05/12/19   1:43 pm - Mabel Infoziant: I will send 2 abst...    1:43 pm
# 9   05/12/19                            1:43 pm - AR❤: Yeah mam    1:43 pm
# 10  05/12/19   1:43 pm - Mabel Infoziant: Give me the list t...    1:43 pm
# 11  05/12/19   1:43 pm - Mabel Infoziant: Send me cbe office...    1:43 pm
# ...

# %%
dataset = df.drop('Chat',axis=1)

# %%
dataset
# Out:
#         Date        Time              Name  \
# 1   05/12/19    1:42 pm    Mabel Infoziant
# 2   05/12/19    1:42 pm    Mabel Infoziant
# 3   05/12/19    1:42 pm                AR❤
# 4   05/12/19    1:42 pm    Mabel Infoziant
# 5   05/12/19    1:42 pm    Mabel Infoziant
# 6   05/12/19    1:43 pm    Mabel Infoziant
# 7   05/12/19    1:43 pm                AR❤
# 8   05/12/19    1:43 pm    Mabel Infoziant
# 9   05/12/19    1:43 pm                AR❤
# 10  05/12/19    1:43 pm    Mabel Infoziant
# 11  05/12/19    1:43 pm    Mabel Infoziant
# 12  05/12/19    1:44 pm                AR❤
# 13  05/12/19    1:45 pm                AR❤
# 14  05/12/19    1:48 pm    Mabel Infoziant
# 15  05/12/19    1:48 pm    Mabel Infoziant
# 16  05/12/19    1:49 pm                AR❤
# 17  05/12/19    2:00 pm                AR❤
# 18  05/12/19    2:04 pm    Mabel Infoziant
# 19  05/12/19    2:04 pm    Mabel Infoziant
# 20  05/12/19    2:06 pm                AR❤
# 21  05/12/19    2:07 pm                AR❤
# ...

# %%
data = dataset.to_csv('Prepro_whatsapp_data.csv',index=False)

# %%
data = pd.read_csv('Prepro_whatsapp_data.csv',index_col=None)
data
# Out:
#         Date        Time              Name  \
# 0   05/12/19    1:42 pm    Mabel Infoziant
# 1   05/12/19    1:42 pm    Mabel Infoziant
# 2   05/12/19    1:42 pm                AR❤
# 3   05/12/19    1:42 pm    Mabel Infoziant
# 4   05/12/19    1:42 pm    Mabel Infoziant
# 5   05/12/19    1:43 pm    Mabel Infoziant
# 6   05/12/19    1:43 pm                AR❤
# 7   05/12/19    1:43 pm    Mabel Infoziant
# 8   05/12/19    1:43 pm                AR❤
# 9   05/12/19    1:43 pm    Mabel Infoziant
# 10  05/12/19    1:43 pm    Mabel Infoziant
# 11  05/12/19    1:44 pm                AR❤
# 12  05/12/19    1:45 pm                AR❤
# 13  05/12/19    1:48 pm    Mabel Infoziant
# 14  05/12/19    1:48 pm    Mabel Infoziant
# 15  05/12/19    1:49 pm                AR❤
# 16  05/12/19    2:00 pm                AR❤
# 17  05/12/19    2:04 pm    Mabel Infoziant
# 18  05/12/19    2:04 pm    Mabel Infoziant
# 19  05/12/19    2:06 pm                AR❤
# 20  05/12/19    2:07 pm                AR❤
# ...

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     50 non-null     object
#  1   Time     50 non-null     object
#  2   Name     50 non-null     object
#  3   Message  50 non-null     object
# dtypes: object(4)
# memory usage: 1.7+ KB

# %%
# import nltk
# nltk.download('vader_lexicon')

# %%
sia = SentimentIntensityAnalyzer()                        # nltk.sentiment.vader.SentimentIntensityAnalyzer.polarity_scores
sentiment = sia.polarity_scores(data['Message'][10])  # Sending a particular text to check the polarity score

# %%
sentiment
# Out:
# {'neg': 0.0, 'neu': 0.915, 'pos': 0.085, 'compound': 0.0772}

# %%
sentiment['compound']
# Out:
# 0.0772

# %%
def SentimentalAnalysis(data, column_name):

    from nltk.sentiment.vader import SentimentIntensityAnalyzer
    sia = SentimentIntensityAnalyzer()   
    
    # Creating the respective columns
    # Forloop for a particular column - Message, apply forloop to all the rows in that column
    data['Scores'] = data[column_name].apply(lambda message : sia.polarity_scores(message))  
    data['Compound'] = data['Scores'].apply(lambda score_dict : score_dict['compound'])
    data['Posivite'] = data['Scores'].apply(lambda score_dict : score_dict['pos'])
    data['Negative'] = data['Scores'].apply(lambda score_dict : score_dict['neg'])
    data['Neutral'] = data['Scores'].apply(lambda score_dict : score_dict['neu'])
    
    data['Feedback'] = data['Compound'].apply(lambda comp: 'Positive Chat' if comp>0 else 'Negative Chat')

    PosNeg = pd.DataFrame(data['Feedback'].value_counts())
    return PosNeg,data

# %%
PosNeg,Senti_data = SentimentalAnalysis(data,column_name = 'Message')

# %%
Senti_data
# Out:
#         Date        Time              Name  \
# 0   05/12/19    1:42 pm    Mabel Infoziant
# 1   05/12/19    1:42 pm    Mabel Infoziant
# 2   05/12/19    1:42 pm                AR❤
# 3   05/12/19    1:42 pm    Mabel Infoziant
# 4   05/12/19    1:42 pm    Mabel Infoziant
# 5   05/12/19    1:43 pm    Mabel Infoziant
# 6   05/12/19    1:43 pm                AR❤
# 7   05/12/19    1:43 pm    Mabel Infoziant
# 8   05/12/19    1:43 pm                AR❤
# 9   05/12/19    1:43 pm    Mabel Infoziant
# 10  05/12/19    1:43 pm    Mabel Infoziant
# 11  05/12/19    1:44 pm                AR❤
# 12  05/12/19    1:45 pm                AR❤
# 13  05/12/19    1:48 pm    Mabel Infoziant
# 14  05/12/19    1:48 pm    Mabel Infoziant
# 15  05/12/19    1:49 pm                AR❤
# 16  05/12/19    2:00 pm                AR❤
# 17  05/12/19    2:04 pm    Mabel Infoziant
# 18  05/12/19    2:04 pm    Mabel Infoziant
# 19  05/12/19    2:06 pm                AR❤
# 20  05/12/19    2:07 pm                AR❤
# ...

# %%
PosNeg
# Out:
#                count
# Feedback
# Negative Chat     28
# Positive Chat     22

# %% [markdown]
# ## Topic Modelling
# ### Using TFIDF & NMF (Non-negative Matrix Factorization) Algorithm

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(max_df = 0.95, min_df = 2, stop_words='english') # df is Document Frequency
mes_vectors = tfidf.fit_transform(data['Message'])
mes_vectors
# Out:
# <50x32 sparse matrix of type '<class 'numpy.float64'>'
# 	with 98 stored elements in Compressed Sparse Row format>

# %%
from sklearn.decomposition import NMF
nmf_model = NMF(n_components=5, random_state = 42)
topic_results = nmf_model.fit_transform(mes_vectors)
topic_results
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 5.72923610e-01,
#         0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         6.82252877e-01],
#        [0.00000000e+00, 6.65009931e-01, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [2.40182638e-01, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         2.93769026e-01],
#        [0.00000000e+00, 7.25516515e-07, 3.62031861e-01, 0.00000000e+00,
#         0.00000000e+00],
#        [2.76237467e-01, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
# ...

# %%
for index,topic in enumerate(nmf_model.components_):
    results = [tfidf.get_feature_names_out()[i] for i in topic.argsort()[-10:]]
    # tfidf.get_feature_names()[i]: Retrieves the actual word corresponding to each index from the TF-IDF feature list.
print('Important Topics : ', results)
# Out:
# Important Topics :  ['students', 'know', 'sure', 'share', 'soon', 'meeting', 'details', 'yes', 'need', 'ramisha']

# %%
data['Topic'] = topic_results.argmax(axis=1)
data
# Out:
#         Date        Time              Name  \
# 0   05/12/19    1:42 pm    Mabel Infoziant
# 1   05/12/19    1:42 pm    Mabel Infoziant
# 2   05/12/19    1:42 pm                AR❤
# 3   05/12/19    1:42 pm    Mabel Infoziant
# 4   05/12/19    1:42 pm    Mabel Infoziant
# 5   05/12/19    1:43 pm    Mabel Infoziant
# 6   05/12/19    1:43 pm                AR❤
# 7   05/12/19    1:43 pm    Mabel Infoziant
# 8   05/12/19    1:43 pm                AR❤
# 9   05/12/19    1:43 pm    Mabel Infoziant
# 10  05/12/19    1:43 pm    Mabel Infoziant
# 11  05/12/19    1:44 pm                AR❤
# 12  05/12/19    1:45 pm                AR❤
# 13  05/12/19    1:48 pm    Mabel Infoziant
# 14  05/12/19    1:48 pm    Mabel Infoziant
# 15  05/12/19    1:49 pm                AR❤
# 16  05/12/19    2:00 pm                AR❤
# 17  05/12/19    2:04 pm    Mabel Infoziant
# 18  05/12/19    2:04 pm    Mabel Infoziant
# 19  05/12/19    2:06 pm                AR❤
# 20  05/12/19    2:07 pm                AR❤
# ...

# %%
data['Topic'].value_counts()
# Out:
# Topic
# 0    22
# 2    12
# 4     6
# 3     5
# 1     5
# Name: count, dtype: int64
